# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# let's take 2 iterations as an assumptions)
N = 2

# identify 100 points to plot the function
x = np.linspace(0,N, 100)
y = np.exp(-2*N*x*x)

plt.plot(x,y)
